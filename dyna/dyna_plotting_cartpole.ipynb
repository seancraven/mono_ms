# %% [markdown]
# ## Collection of terrible Graphs.
# Graphs are plots of model based dyna implementation, without any annotations bedcause I am lazy.

# %%
import jax
import matplotlib.pyplot as plt

from dyna.training import make_dyna_train_fn 
from model_based.transition_models import EquiModel, Model
from model_based.nn_model import NNCartPole 
from dyna.types import ActorCriticHyperParams, DynaHyperParams, TransitionModelHyperParams 
import numpy as np
import jax.numpy as jnp
import matplotlib
matplotlib.rcParams.update({'text.usetex': True, "font.family": "serif"})

# %%
NUM_UPDATES = 5
TM_LR = 1e-4
AC_LR = 3.5e-4
NUM_SEEDS = 16 
NUM_ENVS = 4
TM_EPOCHS = 20
PR = 0.2

ac_hyp = ActorCriticHyperParams(NUM_UPDATES=200, NUM_EPOCHS=1, LR=AC_LR, PRIV_NUM_TIMESTEPS=128)
eqi_hyp = TransitionModelHyperParams(MODEL_FN=EquiModel,LR=TM_LR, NUM_EPOCHS=TM_EPOCHS, )
tm_hyp = TransitionModelHyperParams(MODEL_FN=Model,LR=TM_LR, NUM_EPOCHS=TM_EPOCHS, )
no_m_hyp = TransitionModelHyperParams(USE_MODEL=False, LR=TM_LR, NUM_EPOCHS=TM_EPOCHS, )
mf_hyp = DynaHyperParams(ac_hyp, no_m_hyp, NUM_UPDATES=NUM_UPDATES, PLANNING_RATIO=PR, NUM_ENVS=NUM_ENVS)
dyna_hyp = DynaHyperParams(ac_hyp, tm_hyp, NUM_UPDATES=NUM_UPDATES, PLANNING_RATIO=PR, NUM_ENVS=NUM_ENVS )
equi_hyp = DynaHyperParams(ac_hyp, eqi_hyp,NUM_UPDATES=NUM_UPDATES, PLANNING_RATIO=PR, NUM_ENVS=NUM_ENVS)

rng = jax.random.PRNGKey(42)
rngs = jax.random.split(rng, NUM_SEEDS)
results= []
hyp = [mf_hyp, dyna_hyp, equi_hyp]
names = ['Model Free', 'Dyna', 'Equi-Dyna']
def stack_tuple_list(tup_list):
    items = [[] for _ in tup_list[0]]
    for tup in tup_list:
        for i, item in enumerate(tup):
            items[i].append(item)
    return tuple([jnp.stack(item) for item in items if item])

    

results = []
for h in hyp[:]:
    train_fn = jax.vmap(make_dyna_train_fn(h, NNCartPole))
    rng_split_fn = jax.vmap(jax.random.split)
    def scan_train(rng_state, _ ):
        res = train_fn(rng_state)
        rng_state = rng_split_fn(rng_state)[:, :, -1]
        _, res_info = res
        return rng_state, res_info
    _, result = jax.lax.scan(
        scan_train,
        rngs,
        None,
        length=5
    )
    results.append(result)
    del scan_train
# Out:
# /home/sean/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:796: UserWarning: Explicitly requested dtype <class 'jax.numpy.int64'> requested in astype is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return getattr(self.aval, name).fun(self, *args, **kwargs)
# /home/sean/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:796: UserWarning: Explicitly requested dtype <class 'jax.numpy.int64'> requested in astype is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return getattr(self.aval, name).fun(self, *args, **kwargs)
# ---------------------------------------------------------------------------
# InconclusiveDimensionOperation            Traceback (most recent call last)
# Cell In[2], line 40
#      38     _, res_info = res
#      39     return rng_state, res_info
# ---> 40 _, result = jax.lax.scan(
#      41     scan_train,
#      42     rngs,
#      43     None,
#      44     length=5
#      45 )
#      46 results.append(result)
#      47 del scan_train
#
#     [... skipping hidden 9 frame]
#
# Cell In[2], line 36, in scan_train(rng_state, _)
#      35 def scan_train(rng_state, _ ):
# ---> 36     res = train_fn(rng_state)
#      37     rng_state = rng_split_fn(rng_state)[:, :, -1]
#      38     _, res_info = res
#
#     [... skipping hidden 3 frame]
#
# File ~/ms_mono/dyna/dyna/training.py:132, in make_dyna_train_fn.<locals>.train(rng)
#     119 dyna_runner_state = DynaRunnerState(
#     120     cartpole_env_state=env_state,
#     121     model_params=model_train_state.params,
#    (...)
#     124     rng=rng_state,
#     125 )
#     126 dyna_state = DynaState(
#     127     dyna_runner_state,
#     128     model_train_state,
#     129     model_env_state,
#     130 )
# --> 132 final_dyna_runner, infos = jax.lax.scan(
#     133     ex_step,
#     134     dyna_state,
#     135     None,
#     136     length=dyna_hyp.NUM_UPDATES,
#     137 )
#     138 return final_dyna_runner, infos
#
#     [... skipping hidden 9 frame]
#
# File ~/ms_mono/dyna/dyna/training.py:193, in make_experience_step.<locals>._experience_step(dyna_state, _)
#     190 final_env_state = dyna_runner_state.cartpole_env_state
#     192 ######
# --> 193 model_train_state, model_losses = env_model_update_fn(
#     194     rng_model, model_train_state, trajectories
#     195 )
#     196 #######
#     197 dyna_runner_state = DynaRunnerState(
#     198     model_params=model_train_state.params,
#     199     train_state=dyna_runner_state.get_train_state(),
#    (...)
#     202     rng=rng_next,
#     203 )
#
# File ~/ms_mono/dyna/dyna/model_higher_order.py:41, in make_transition_model_update.<locals>.tm_update_fn(rng, train_state, trajectories)
#      39 perm = jax.random.permutation(rng, data.state.shape[0])
#      40 data = jax.tree_map(lambda x: x.at[perm].get(), data)
# ---> 41 batched_data = jax.tree_map(
#      42     lambda x: x.reshape(no_mini_batch, -1, x.shape[-1]), data
#      43 )
#      45 def _epoch(
#      46     train_state: TrainState,
#      47     _,
#      48 ) -> Tuple[TrainState, EnvModelLosses]:
#      49     state, losses = jax.lax.scan(mini_batch_fn, train_state, batched_data)
#
#     [... skipping hidden 2 frame]
#
# File ~/ms_mono/dyna/dyna/model_higher_order.py:42, in make_transition_model_update.<locals>.tm_update_fn.<locals>.<lambda>(x)
#      39 perm = jax.random.permutation(rng, data.state.shape[0])
#      40 data = jax.tree_map(lambda x: x.at[perm].get(), data)
#      41 batched_data = jax.tree_map(
# ---> 42     lambda x: x.reshape(no_mini_batch, -1, x.shape[-1]), data
#      43 )
#      45 def _epoch(
#      46     train_state: TrainState,
#      47     _,
#      48 ) -> Tuple[TrainState, EnvModelLosses]:
#      49     state, losses = jax.lax.scan(mini_batch_fn, train_state, batched_data)
#
# File ~/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:796, in _forward_method_to_aval.<locals>.meth(self, *args, **kwargs)
#     795 def meth(self, *args, **kwargs):
# --> 796   return getattr(self.aval, name).fun(self, *args, **kwargs)
#
# File ~/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:143, in _reshape(a, order, *args)
#     138 def _reshape(a: Array, *args: Any, order: str = "C") -> Array:
#     139   """Returns an array containing the same data with a new shape.
#     140
#     141   Refer to :func:`jax.numpy.reshape` for full documentation.
#     142   """
# --> 143   newshape = _compute_newshape(a, args[0] if len(args) == 1 else args)
#     144   if order == "C":
#     145     return lax.reshape(a, newshape, None)
#
# File ~/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:133, in _compute_newshape(a, newshape)
#     131   if sz is not None:
#     132     return (*newshape[:i], sz, *newshape[i+1:])
# --> 133 return tuple(-core.divide_shape_sizes(np.shape(a), newshape)
#     134              if core.symbolic_equal_dim(d, -1) else d
#     135              for d in newshape)
#
# File ~/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:133, in <genexpr>(.0)
#     131   if sz is not None:
#     132     return (*newshape[:i], sz, *newshape[i+1:])
# --> 133 return tuple(-core.divide_shape_sizes(np.shape(a), newshape)
#     134              if core.symbolic_equal_dim(d, -1) else d
#     135              for d in newshape)
#
#     [... skipping hidden 1 frame]
#
# File ~/ms_mono/.venv/lib/python3.10/site-packages/jax/_src/core.py:1881, in DimensionHandler.divide_shape_sizes(self, s1, s2)
#    1879   return 1
#    1880 if sz1 % sz2:
# -> 1881   raise InconclusiveDimensionOperation(f"Cannot divide evenly the sizes of shapes {tuple(s1)} and {tuple(s2)}")
#    1882 return sz1 // sz2
#
# InconclusiveDimensionOperation: Cannot divide evenly the sizes of shapes (112399, 4) and (8, -1, 4)

# %%
def moving_average(x, w=100):
    return np.convolve(x, np.ones(w), "valid") / w
fig, ax = plt.subplots(1, 2, figsize=(16, 5))
cs = ["black", "blue", "indigo"]
for res, name, c in zip(results, names, cs):
    traj = res[1]
    # acting_returns = 1 - traj.info["returned_episode_returns"]/ 500
    # ax[0].set_ylim(1e-2, 1)
    # ax[1].set_ylim(1e-2, 1)
    acting_returns = traj.info["returned_episode_returns"]
    acting_returns = acting_returns.reshape(np.prod(acting_returns.shape[:2]), -1)
    acting_returns_mean = jnp.mean(acting_returns, axis=0).reshape(-1)
    acting_returns_std = jnp.std(acting_returns, axis=0).reshape(-1)/ np.sqrt(NUM_SEEDS)
    acting_returns_mean = moving_average(acting_returns_mean)
    acting_returns_std = moving_average(acting_returns_std)
    lower = acting_returns_mean - acting_returns_std
    upper = acting_returns_mean + acting_returns_std
    x = jnp.arange(len(acting_returns_mean))
    ax[0].plot(acting_returns_mean, color=c)
    ax[0].fill_between(jnp.arange(len(acting_returns_mean)), lower, upper, alpha=0.3,  label=name, color=c, )
    ax[0].legend()    
    ax[0].set_xlabel("MDP Interations")
    ax[0].set_ylabel("Episodic Return")
    cumulative_returns = np.cumsum(acting_returns, axis=1)[:, -1]
    worst_decile = np.quantile(cumulative_returns, 0.1)
    worst_mean = acting_returns[cumulative_returns < worst_decile].mean(axis=0)
    worst_std = acting_returns[cumulative_returns < worst_decile].std(
        axis=0
    ) / np.sqrt(NUM_SEEDS)
    worst_upper = worst_mean + worst_std
    worst_lower = worst_mean - worst_std
    ax[1].plot(
        x,
        moving_average(worst_mean),
        label=f"{name} (worst decile)",
        linestyle="--",
        color=c,
    )
    ax[1].fill_between(
        x,
        moving_average(worst_lower),
        moving_average(worst_upper),
        alpha=0.3,
        color=c,
    )
    ax[1].set_xlabel("Timesteps")
    ax[1].set_ylabel("Worst Decile Episodic Return")

ax[0].legend()
ax[1].legend()
fig.savefig("plots.png")

# %%
for info, name in zip(results[1:], names[1:]):
    m_loss= info[-1]
    plt.plot(m_loss.mean(axis=(0, 1)).reshape(-1),  label=name)
    print(jnp.min(m_loss.mean(axis=(0, 1)).reshape(-1)))
    
plt.legend()
# Out:
# 0.08202379
# 0.058698714
